# %% [markdown]
# # VECTRI India experiment
#
# The newly released documentation is [available here] (https://users.ictp.it/~tompkins/vectri/documentation/index.html).
#
# To run locally on your machine you will need to follow section 2 of the guide to show you how to set up the pre-requisite environmental variables and which software you require.
#
# <div class="alert alert-block alert-warning">
# The VECTRI documentation is work in progress, some of the more advanced usage sections are still to be written
# </div>

# %% [markdown]
# # Gridded India experiments

# %%
#%pip install wget
import wget
import os.path
datadir="/Users/tompkins/v_test/run2/"
url="http://clima-dods.ictp.it/Users/tompkins/monsoons/india/"
files=["IMD_india_rain_1x1.nc","IMD_india_t2m_1x1.nc","india_pop_1x1.nc"]
for file in files:
    if not os.path.isfile(datadir+file):
        wget.download(url+file,out=datadir)
# Out:
#   0% [                                                                    ]   1040384 / 115308305
#   1% [.                                                                   ]   2195456 / 115308305
#   2% [.                                                                   ]   3366912 / 115308305
#   4% [..                                                                  ]   4685824 / 115308305
#   5% [...                                                                 ]   5955584 / 115308305
#   6% [....                                                                ]   7184384 / 115308305
#   7% [.....                                                               ]   8814592 / 115308305
#   8% [.....                                                               ]   9961472 / 115308305
#  10% [.......                                                             ]  12115968 / 115308305
#  11% [.......                                                             ]  13443072 / 115308305
# ...
