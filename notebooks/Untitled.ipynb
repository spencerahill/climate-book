# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display

def pltsin(ax,f, hdisplay):
    x=y=np.linspace(0,1,100)
    z=np.random.random(size=(100,100))
    ax.contourf(x,y,z)
    ax.set_title(str(f))
    hdisplay.update(fig)


fig,ax = plt.subplots(2)
hdisplay = display.display("", display_id=True)

ax[0].set_xlabel('X')
ax[0].set_ylabel('Y')
ax[0].set_xlim(0,1)
ax[0].set_ylim(0,1)
ax[0].set_aspect('equal','box')

for f in range(5):
    pltsin(ax[0], f, hdisplay=hdisplay)
    time.sleep(1)

lplot=False
if lplot==True:
    print("yest")

print (np.zeros([3,3]))
plt.close(fig)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
x=np.full(4,np.nan)
levs=np.linspace(0,1,21)
levs
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ])
